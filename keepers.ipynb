# %%
import pandas as pd

# %%
df = pd.read_csv('keepers.csv')

# %%
df.sort_values(by='Tier')
# Out:
#                  Player Team Position  Salary  ?  Floor  Points  Ceiling  \
# 8         Myles Garrett  Cle       DE       9  1   68.8    75.5     82.0
# 10        Justin Tucker  Bal        K       6  9  148.0   157.0    169.0
# 5        Darius Leonard  Ind       LB      11  7  104.0   109.0    113.0
# 7           Jamal Adams  Sea        S      10  5   99.7   101.0    103.0
# 0   Christian McCaffrey  Car       RB      53  9  223.0   247.0    310.0
# 3           Jalen Hurts  Phi       QB      18  7  328.0   353.0    384.0
# 2         Aaron Rodgers   GB       QB      20  8  310.0   330.0    346.0
# 16       Dallas Goedert  Phi       TE       1  2   99.3   115.0    127.0
# 4        Terry McLaurin  Was       WR      17  6  126.0   145.0    170.0
# 11         J.K. Dobbins  Bal       RB       1  2  150.0   173.0    209.0
# 6         Miles Sanders  Phi       RB      11  7  148.0   156.0    182.0
# 9         Robert Tonyan   GB       TE       8  1   68.2    79.7    101.0
# ...
